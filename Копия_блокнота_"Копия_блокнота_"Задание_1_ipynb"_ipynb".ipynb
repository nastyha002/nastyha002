# %% [markdown]
# <a href="https://colab.research.google.com/github/nastyha002/nastyha002/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1_ipynb%22_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Global YouTube Statistics.csv', encoding='windows-1252')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
print(df.head(5))
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
print(df.tail(5))
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
print(df.describe(include="all"))
# Out:
#              rank  Youtuber   subscribers   video views       category  \
# count   995.00000       995  9.950000e+02  9.950000e+02            949
# unique        NaN       995           NaN           NaN             18
# top           NaN  T-Series           NaN           NaN  Entertainment
# freq          NaN         1           NaN           NaN            241
# mean    498.00000       NaN  2.298241e+07  1.103954e+10            NaN
# std     287.37606       NaN  1.752611e+07  1.411084e+10            NaN
# min       1.00000       NaN  1.230000e+07  0.000000e+00            NaN
# 25%     249.50000       NaN  1.450000e+07  4.288145e+09            NaN
# 50%     498.00000       NaN  1.770000e+07  7.760820e+09            NaN
# 75%     746.50000       NaN  2.460000e+07  1.355470e+10            NaN
# max     995.00000       NaN  2.450000e+08  2.280000e+11            NaN
#
#           Title        uploads        Country Abbreviation   channel_type  \
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# *Курсив*
#
# 1.   subscribers - 22982412.060302, video views - 1.103954e+10, uploads - 9187.125628, subscribers_for_last_30_days - 3.490791e+05, created_year - 2012.630303 created_date - 15.746465, Gross tertiary education enrollment (%) - 63.627752 Population - 4.303873e+08, Unemployment rate - 9.279278, Urban_population - 2.242150e+08, Latitude - 26.632783 Longitude - -14.128146
# 2. subscribers - min: 12300000.0 max:245000000.0 , video views - min:0.000000e+00 max:2.280000e+11 , uploads min:0.000000 max:301308.000000 , subscribers_for_last_30_days min:1.000000e+00 max:8.000000e+06 , created_year min:1970.000000 max:2022.000000 created_date min:1.000000 max: 31.000000 , Gross tertiary education enrollment (%) - min:7.600000 max:113.100000, Population min:2.025060e+05 max:1.397715e+09 , Unemployment rate min:0.750000 max:14.720000 , Urban_population min:3.558800e+04 max: 8.429340e+08 , Latitude min:-38.416097 max:61.924110 Longitude - min:-172.104629 max:138.252924

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
"""
df = df.astype({"a": "Int64"})

df = df.astype({"a": "float64"})

"""
df.Youtuber = df.Youtuber.astype("category")
df.category = df.category.astype("category")
df.Title = df.Title.astype("category")
df.Country = df.Country.astype("category")
df.Abbreviation = df.Abbreviation.astype("category")
df.channel_type = df.channel_type.astype("category")
df.created_month = df.created_month.astype("category")
print(df.dtypes)
# Out:
# rank                                          int64
# Youtuber                                   category
# subscribers                                   int64
# video views                                 float64
# category                                   category
# Title                                      category
# uploads                                       int64
# Country                                    category
# Abbreviation                               category
# channel_type                               category
# video_views_rank                            float64
# country_rank                                float64
# channel_type_rank                           float64
# video_views_for_the_last_30_days            float64
# lowest_monthly_earnings                     float64
# highest_monthly_earnings                    float64
# lowest_yearly_earnings                      float64
# highest_yearly_earnings                     float64
# ...

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# Ответ:
# subscribers - числовые-количественные rank - числовые-порядковые category - категориальные

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
df[df["rank"] < 10]
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# ...

# %%
df[df["subscribers"] < 100000000]
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 9      10             Vlad and Niki     98900000  7.718017e+10
# 10     11         Zee Music Company     96700000  5.785629e+10
# 11     12                       WWE     96000000  7.742847e+10
# 12     13                    Gaming     93600000  0.000000e+00
# 13     14                 BLACKPINK     89800000  3.214460e+10
# ..    ...                       ...          ...           ...
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 9     Entertainment             Vlad and Niki      574   United States
# ...

# %%
df[df["uploads"] < 10]
# Out:
#      rank               Youtuber  subscribers   video views          category  \
# 1       2         YouTube Movies    170000000  0.000000e+00  Film & Animation
# 5       6                  Music    119000000  0.000000e+00               NaN
# 12     13                 Gaming     93600000  0.000000e+00               NaN
# 14     15              Goldmines     86900000  2.411823e+10  Film & Animation
# 16     17        5-Minute Crafts     80100000  2.623679e+10     Howto & Style
# ..    ...                    ...          ...           ...               ...
# 967   968  Troom Troom Indonesia     12500000  5.379684e+09    People & Blogs
# 975   976      Gustavo Parï¿½ï¿½     12400000  2.602614e+09            Comedy
# 983   984               MoniLina     12400000  1.608681e+10            Comedy
# 985   986                   TKOR     12400000  3.392023e+09         Education
# 986   987              ANNA KOVA     12400000  1.395959e+10    People & Blogs
#
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df.groupby(["subscribers"]).count()
# Out:
#              rank  Youtuber  video views  category  Title  uploads  Country  \
# subscribers
# 12300000        5         5            5         4      5        5        5
# 12400000       20        20           20        19     20       20       17
# 12500000       22        22           22        20     22       22       19
# 12600000        5         5            5         5      5        5        5
# 12700000       13        13           13        10     13       13       10
# ...           ...       ...          ...       ...    ...      ...      ...
# 159000000       1         1            1         1      1        1        1
# 162000000       1         1            1         1      1        1        1
# 166000000       1         1            1         1      1        1        1
# 170000000       1         1            1         1      1        1        1
# 245000000       1         1            1         1      1        1        1
#
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
